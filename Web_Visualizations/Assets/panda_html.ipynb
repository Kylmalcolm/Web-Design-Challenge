# %%
import pandas as pd
import numpy as np

# %%
city_df = pd.read_csv("city_data.csv")
city_df
# Out:
#                  City  Latitude  Longitude  Max Temperature  Humidity  \
# 0             Rikitea    -23.12    -134.97            75.99        83
# 1           Busselton    -33.65     115.33            48.00        98
# 2          Nikolskoye     59.70      30.79            32.00        86
# 3    Puerto Escondido     15.85     -97.07            84.20        70
# 4             Ushuaia    -54.80     -68.30            44.60        65
# ..                ...       ...        ...              ...       ...
# 559   Plettenberg Bay    -34.05      23.37            62.69        85
# 560           Kuantan      3.81     103.33            77.00        94
# 561             Amapá      1.00     -52.00            74.89        93
# 562         Iskateley     67.68      53.15            28.47        98
# 563     Saint Anthony     45.02     -93.22            36.00        93
#
#      Cloudiness  Wind Speed Country        Date
# 0            81       17.27      PF  1605389950
# ...

# %%
table = city_df.to_html()
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Rikitea</td>
#       <td>-23.12</td>
#       <td>-134.97</td>
#       <td>75.99</td>
#       <td>83</td>
#       <td>81</td>
#       <td>17.27</td>
#       <td>PF</td>
#       <td>1605389950</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Busselton</td>
#       <td>-33.65</td>
#       <td>115.33</td>
#       <td>48.00</td>
#       <td>98</td>
#       <td>3</td>
#       <td>13.47</td>
#       <td>AU</td>
#       <td>1605389951</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Nikolskoye</td>
#       <td>59.70</td>
#       <td>30.79</td>
# ...
